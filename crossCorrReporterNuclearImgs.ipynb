# %%
from matplotlib.patches import Patch
import sys, time, math
import matplotlib.pyplot as plt
import numpy as np
sys.path.append('/home/groups/ZuckermanLab/jalim/instalLocal/celltraj/celltraj')
import sctmCP_Dec15_2023 as cellTraj
import cellCycRepJCtrajsCP as cellTrajCCR
from csaps import csaps
import string, pickle 
from datetime import date
from skimage import io, measure
from IPython.display import clear_output
from matplotlib.animation import FuncAnimation

# %%
# Trajectory Length for morphodynamical trajectory analysis
trajl = 1
today = date.today()
date2day = today.strftime("%b%d-%Y")
sysName = 'LI204601_P'
figid = sysName+'_tlen'+str(trajl)+'_'+date2day
#conditions = ['A1','A2','A3','A4','A5','B1','B2','B3','B4','B5','C1','C2','C3'] # LIGANDS (CONDITIONS)
#tmSet = ['OSM1','EGF1','EGF+TGFB1','TGFB1','PBS1','OSM2','EGF2','EGF+TGFB2','TGFB2','PBS2',
#         'OSM+EGF+TGFB','OSM+EGF','OSM+TGFB']
conditions = ['A2'] # LIGANDS (CONDITIONS)
tmSet = ['EGF1']
nConditions = len(tmSet) # Total number of Ligand Conditions
inds_tmSet = [i for i in range(nConditions)]
inds_tmSet = np.array(inds_tmSet).astype(int)
#nfovs = 4
nfovs = 1
fovs = [i for i in range(1, nfovs + 1)]
fovs = np.array(fovs).astype(int)
dateSet = ['']
pathSet = ['/home/groups/ZuckermanLab/jalim/LI204601_INCUCYTE/segsCellPose/bayesianTrackTest/znormRegPhaseImgs/']
imagingSet = [0 for i in range(nConditions)]
modelList = [None]*(nfovs*(nConditions))
modelList_conditions = np.zeros(nfovs*(nConditions)).astype(int)

# %%
i = 0
icond = 0
for cond in conditions:
    for fov in fovs:
        modelList_conditions[i] = icond
        modelList[i] = pathSet[imagingSet[icond]]+sysName+'_'+cond+'_'+str(fov)+dateSet[imagingSet[icond]]
        #print("Models: ",modelList[i])
        i = i + 1
    icond = icond + 1

# %%
nmodels = len(modelList)
modelSet = [None]*nmodels
indgood_models = np.array([]).astype(int)

for i in range(nmodels):
    try:
        objFile = modelList[i]+'.obj'
        objFileHandler = open(objFile,'rb')
        modelSet[i] = pickle.load(objFileHandler)
        print('loaded '+objFile+' with '+str(modelSet[i].cells_indSet.size)+' cells')
        objFileHandler.close()
        test = len(modelSet[i].linSet)
        indgood_models = np.append(indgood_models,i)
    except:
        print("ERROR in reading *.obj files")
        sys.exit(0)
# Out:
# loaded /home/groups/ZuckermanLab/jalim/LI204601_INCUCYTE/segsCellPose/bayesianTrackTest/znormRegPhaseImgs/LI204601_P_A2_1.obj with 51054 cells

# %%
# Total number of frames (image snapshots) in one condition per FOVs
nframes = 193 
cellnumber_stdSet = np.ones(nmodels)*np.inf
# range of frame indices where cell numbers are higher: ~70-98%
sframe = 70.*nframes/100.; sframe = math.ceil(sframe)
eframe = 98.5*nframes/100.; eframe = math.ceil(eframe)
cellnumber_frames = np.arange(sframe, eframe).astype(int)
cellnumber_std_cut = .50 # This was set to 0.10 by Jeremy 
frames = np.arange(nframes)
# Abscissas at which smoothing will be done using CSAPS package
abSmooth = np.linspace(frames[0], frames[-1], 10000)

for i in indgood_models:
    ncells = np.zeros(nframes)
    ncells_smooth = np.zeros_like(ncells)
    for iS in range(nframes):
        ncells[iS]=np.sum(modelSet[i].cells_frameSet == iS)
    # Cubic Spline Approximation (CSAPS) to smoothen the data
    splfov = csaps(frames, ncells/ncells[0], abSmooth, smooth = 0.98) # Scaled by ncells[0] to avoid large numbers
    ncells_smooth = splfov*ncells[0] # smoothened cell numbers reverse scaled back to original
    cellnumber_std = np.std(ncells[cellnumber_frames] - ncells_smooth[cellnumber_frames])/np.mean(ncells[cellnumber_frames])
    cellnumber_stdSet[i] = cellnumber_std # Standard Deviation in Cell Numbers

# %%
indhigh_std = np.where(cellnumber_stdSet > cellnumber_std_cut)[0]
indgood_models = np.setdiff1d(indgood_models, indhigh_std)
#indgood_models = np.setdiff1d(indgood_models, np.array([51]).astype(int)) #missing comdx for EGF0_4

# get cell counts
nf = len(tmSet)
inds_tmSet_models = np.zeros(nmodels).astype(int)
inds_imagingSet_models = np.zeros(nmodels).astype(int)
i = 0
icond = 0
for cond in conditions:
    for fov in fovs:
        inds_tmSet_models[i] = inds_tmSet[icond]
        inds_imagingSet_models[i] = imagingSet[icond]
        i = i + 1
    icond = icond + 1

# %%
for i in indgood_models:
    if inds_imagingSet_models[i] == 0:
        modelSet[i].Xf[np.isnan(modelSet[i].Xf)] = 0.0 #just replace with zeros for now? Not sure best...

nfeat_com = 3
Xf_com0 = np.zeros((0, nfeat_com))
for i in indgood_models:
    if inds_imagingSet_models[i] == 0:
        Xf_com0 = np.append(Xf_com0,modelSet[i].Xf_com, axis = 0)

av_dx = np.nanmean(Xf_com0[:, 0])
std_dx = np.nanstd(Xf_com0[:, 0])
for i in indgood_models:
    modelSet[i].Xf_com[:, 0] = (modelSet[i].Xf_com[:, 0] - av_dx)/std_dx

# %%
wctm = cellTraj.Trajectory() # import Trajectory object 

nfeat = modelSet[indgood_models[0]].Xf.shape[1]
Xf = np.zeros((0, nfeat))
indtreatment = np.array([])
indcellSet = np.array([])
for i in indgood_models:
    if inds_imagingSet_models[i] == 0:
        Xf = np.append(Xf, modelSet[i].Xf, axis = 0)
        indtreatment = np.append(indtreatment, i*np.ones(modelSet[i].Xf.shape[0]))
        indcellSet = np.append(indcellSet, modelSet[i].cells_indSet)

indtreatment = indtreatment.astype(int)
indcellSet = indcellSet.astype(int)

# %%
# Use the sklearn package (intended for ease of use over performance/scalability)
varCutOff = 10 # changed from 10 to 6 to match with JC's notebook
from sklearn.decomposition import PCA 
# n_components specifies the number of principal components to extract from the covariance matrix
pca = PCA(n_components = varCutOff) 
pca.fit(Xf) # builds the covariance matrix and "fits" the principal components
Xpca = pca.transform(Xf) # transforms the data into the pca representation
nPCs = Xpca.shape[1]

# %%
wctm.Xpca = Xpca
wctm.pca = pca
for i in indgood_models:
    if inds_imagingSet_models[i] == 0:
        indsf = np.where(indtreatment == i)[0]
        modelSet[i].Xpca = Xpca[indsf, :]

indgood_models = indgood_models[np.where(inds_imagingSet_models[indgood_models] == 0)[0]]

# %%
self = wctm
#wctm.trajl = trajl
all_trajSet = [None]*nmodels
for i in indgood_models:
    #modelSet[i].get_unique_trajectories(verbose = True)
    modelSet[i].get_unique_trajectories()
# Out:
# tracked cell 50900, 23 tracks, 47500 left
# tracked cell 50701, 41 tracks, 41900 left
# tracked cell 50625, 52 tracks, 39700 left
# tracked cell 49059, 3 tracks, 38700 left
# tracked cell 47575, 34 tracks, 38100 left
# tracked cell 44782, 17 tracks, 36900 left
# tracked cell 43429, 1 tracks, 36400 left
# tracked cell 42537, 1 tracks, 36200 left
# tracked cell 39844, 25 tracks, 34200 left
# tracked cell 38077, 21 tracks, 32900 left
# tracked cell 36361, 6 tracks, 31700 left
# tracked cell 35482, 1 tracks, 31400 left
# tracked cell 34248, 2 tracks, 31100 left
# tracked cell 33966, 5 tracks, 31000 left
# tracked cell 31034, 1 tracks, 30400 left
# tracked cell 30880, 1 tracks, 30300 left
# tracked cell 30574, 1 tracks, 30000 left
# tracked cell 30191, 21 tracks, 28100 left
# tracked cell 30076, 13 tracks, 26800 left
# tracked cell 29967, 34 tracks, 26200 left
# tracked cell 29646, 2 tracks, 25400 left
# tracked cell 28784, 15 tracks, 24100 left
# tracked cell 28276, 12 tracks, 23800 left
# tracked cell 25762, 1 tracks, 22900 left
# tracked cell 23775, 2 tracks, 22000 left
# tracked cell 22543, 18 tracks, 20400 left
# tracked cell 21716, 1 tracks, 18800 left
# tracked cell 21639, 3 tracks, 18700 left
# tracked cell 21540, 1 tracks, 18300 left
# tracked cell 21094, 15 tracks, 17300 left
# tracked cell 20930, 73 tracks, 16800 left
# tracked cell 20777, 20 tracks, 16400 left
# tracked cell 20719, 1 tracks, 16200 left
# tracked cell 18965, 2 tracks, 14300 left
# tracked cell 18051, 16 tracks, 13700 left
# tracked cell 17346, 2 tracks, 13200 left
# tracked cell 16751, 2 tracks, 12900 left
# tracked cell 12442, 1 tracks, 9800 left
# tracked cell 10703, 3 tracks, 8200 left
# tracked cell 10300, 1 tracks, 7800 left
# tracked cell 9749, 1 tracks, 7000 left
# tracked cell 9455, 1 tracks, 6800 left
# tracked cell 8934, 3 tracks, 6500 left
# tracked cell 8819, 6 tracks, 6300 left
# tracked cell 8124, 21 tracks, 5900 left
# tracked cell 7340, 41 tracks, 5200 left
# tracked cell 5796, 5 tracks, 4200 left
# tracked cell 4882, 1 tracks, 3400 left
# tracked cell 4181, 2 tracks, 2200 left
# tracked cell 3890, 20 tracks, 1900 left
# tracked cell 1187, 2 tracks, 300 left
# tracked cell 12, 1 tracks, 0 left

# %%
for i in indgood_models:
    # Set of all single-cell trajectories with absolute (irrespective of frames) cell indices
    num_single_cell_trajs = len(modelSet[i].trajectories)
    
    single_cell_traj_lengths = []
    for itraj in range(num_single_cell_trajs):
        single_cell_traj_inds = modelSet[i].trajectories[itraj] # Indices of single-cell trajectory across frames
        single_cell_traj_length = len(single_cell_traj_inds) # Length of a single-cell trajectory
        single_cell_traj_lengths.append(single_cell_traj_length)  
    indtrajs = np.argsort(single_cell_traj_lengths) # Length ordered array of unique single-cell trajectories

# %%
############ Find the longest single-cell trajectory ############
longest_trajectory = max(single_cell_traj_lengths) 
if longest_trajectory > nframes: 
    print("Error: longest single-cell trajectory can't exceed total number of frames")
    sys.exit(0)
#print("Longest single-cell trajectory length: ",longest_trajectory)
ind_longest_trajectory = np.argmax(single_cell_traj_lengths) # Index of the longest single-cell trajectory
#print("Index of longest single-cell trajectory: ",ind_longest_trajectory)
cell_inds_longest_traj = modelSet[i].trajectories[ind_longest_trajectory] # Cell indices
#print("Cell indices of the longest single-cell trajectory: ",cell_inds_longest_traj)

# %%
# Make a plot of cell coordinate and single-cell images along a cell trajectory
def show_cell_trajectory(self, cell_traj, x = None, traj = None, nbins = 100): 
    if x is None:
        x = self.Xtraj
    if traj is None:
        traj = self.traj
    plt.figure(figsize = (12, 6))
    prob, xedges1, yedges1 = np.histogram2d(x[:, 0], x[:, 1], bins = nbins, density = True) # Coordinate landscape probability distribution
    xx, yy = np.meshgrid(.5*xedges1[1:] + .5*xedges1[0:-1], .5*yedges1[1:] + .5*yedges1[0:-1]) # Grid coordinates
    xt, inds_traj = self.get_Xtraj_celltrajectory(cell_traj, Xtraj = x, traj = traj) # Get coordinates & cell indices along a trajectory set
    cell_traj = self.traj[inds_traj,-1]
    nt = cell_traj.size # Total number of single-cell trajectories 
    icell = cell_traj[-1]
    for itt in range(nt):
        clear_output(wait = True)
        plt.clf()
        plt.subplot(1, 2, 1)
        # Single-cell trajectory distribution for a given snippet length
        cs = plt.contourf(xx, yy, prob.T, cmap = plt.cm.Greys, extend = 'both') 
        cs.cmap.set_over('black')
        plt.axis('off')
        ax = plt.gca()
        for ittt in range(itt - 1):
            ax.arrow(xt[ittt, 0], xt[ittt, 1], xt[ittt+1, 0] - xt[ittt, 0], xt[ittt+1, 1] - xt[ittt, 1],
                     head_width = .2, linewidth = 1.0, color = plt.cm.winter(ittt/nt), alpha = 1.0) # Along a selected trajectory
        plt.subplot(1, 2, 2)
        self.get_cellborder_images(indcells = np.array([cell_traj[itt]]), bordersize = 60) # Originally bordersize = 80, kept by JC
        imgcell = self.cellborder_imgs[0]
        mskcell = self.cellborder_msks[0]
        fmskcell = self.cellborder_fmsks[0]
        #ccborder, csborder = self.get_cc_cs_border(mskcell, fmskcell)
        plt.imshow(np.ma.masked_where(fmskcell == 0, imgcell), cmap = plt.cm.seismic, clim = (-5, 5), alpha = 1.0)
        plt.imshow(np.ma.masked_where(fmskcell == 1, imgcell), cmap = plt.cm.gray, clim = (-5, 5), alpha = 0.6)
        nx = imgcell.shape[0]
        ny = imgcell.shape[1]
        xxc, yyc = np.meshgrid(np.arange(nx), np.arange(ny), indexing='ij')
        cmskx = np.sum(np.multiply(xxc, mskcell))/np.sum(mskcell)
        cmsky = np.sum(np.multiply(yyc, mskcell))/np.sum(mskcell)
        scatter_x = plt.scatter(cmsky, cmskx, s = 600, color = 'black', marker = 'x', alpha = 0.6)
        plt.axis('off')
        plt.pause(.33)

# %%
model_indc = 0
modelSet[model_indc].trajl = 1
# Get trajectory segments of a given snippet length, to be consistent with trajectory embeddings
modelSet[model_indc].traj = modelSet[model_indc].get_traj_segments(1) 
cell_traj = modelSet[model_indc].trajectories[indtrajs[-10]]
show_cell_trajectory(modelSet[model_indc], cell_traj, x = modelSet[model_indc].Xpca[:, 0:2], traj = modelSet[model_indc].traj)

# %% [markdown]
# Concatenates PCA features along trajectories of length "trajl = traj_snip_length", and then embeds morphodynamical feature trajectory into a UMAP of dimension "neigen" = 2

# %%
trajl = 33 # 8 hrs
modelSet[model_indc].get_trajectory_embedding(trajl, embedding_type = 'UMAP', neigen = 2, get_trajectories = False)
show_cell_trajectory(modelSet[model_indc], modelSet[model_indc].trajectories[indtrajs[-10]], 
                     x = modelSet[model_indc].Xtraj, traj = modelSet[model_indc].traj)

# %%
# Plot of cell coordinates and images along a single-cell trajectory
def show_single_cell_trajectory(self, cell_traj): 
    plt.figure(figsize = (8, 4))
    nt = cell_traj.size # Number of single-cell trajectory snippets
    
    for itt in range(nt):
        clear_output(wait = True)
        plt.clf()
        indcells = np.array([cell_traj[itt]]) # Index of a cell along its trajectory 
        fid = self.cells_frameSet[indcells]
        print("Frame: ",fid)
        self.get_cellborder_images(indcells = indcells, bordersize = 60) # Originally bordersize = 80, kept by JC
        imgcell = self.cellborder_imgs[0]
        mskcell = self.cellborder_msks[0]
        fmskcell = self.cellborder_fmsks[0]
        ccborder, csborder = self.get_cc_cs_border(mskcell, fmskcell)
        plt.imshow(np.ma.masked_where(fmskcell == 0, imgcell), cmap = plt.cm.seismic, clim = (-5, 5), alpha = 1.0)
        plt.imshow(np.ma.masked_where(fmskcell == 1, imgcell), cmap = plt.cm.gray, clim = (-5, 5), alpha = 0.6)
        plt.imshow(np.ma.masked_where(ccborder == 1, mskcell, copy = False), cmap = plt.cm.viridis, alpha = 0.2)
        nx = imgcell.shape[0]
        ny = imgcell.shape[1]
        xxc, yyc = np.meshgrid(np.arange(nx), np.arange(ny), indexing='ij')
        cmskx = np.sum(np.multiply(xxc, mskcell))/np.sum(mskcell)
        cmsky = np.sum(np.multiply(yyc, mskcell))/np.sum(mskcell)
        plt.scatter(cmsky, cmskx, s = 600, color = 'black', marker = 'x', alpha = 0.6)
        plt.axis('off')
        plt.pause(.33)

# %%
model_indc = 0
cell_traj = modelSet[model_indc].trajectories[indtrajs[-10]]
show_single_cell_trajectory(modelSet[model_indc], cell_traj)

# %%
def anim_single_cell_trajectory(self, cell_traj, x=None):
    if x is None:
        x = self.Xtraj

    filename='single_cell_trajectory'
    fig, ax = plt.subplots(figsize=(8, 4))
    nt = cell_traj.size

    def update(itt):
        clear_output(wait=True)
        ax.clear()
        self.get_cellborder_images(indcells=np.array([cell_traj[itt]]), bordersize=60)
        imgcell = self.cellborder_imgs[0]
        mskcell = self.cellborder_msks[0]
        fmskcell = self.cellborder_fmsks[0]
        ccborder, csborder = self.get_cc_cs_border(mskcell, fmskcell)
        ax.imshow(np.ma.masked_where(fmskcell == 0, imgcell), cmap=plt.cm.seismic, clim=(-5, 5), alpha=1.0)
        ax.imshow(np.ma.masked_where(fmskcell == 1, imgcell), cmap=plt.cm.gray, clim=(-5, 5), alpha=0.6)
        ax.imshow(np.ma.masked_where(ccborder == 1, mskcell, copy=False), cmap=plt.cm.copper, alpha=0.25)
        nx, ny = imgcell.shape[0], imgcell.shape[1]
        xxc, yyc = np.meshgrid(np.arange(nx), np.arange(ny), indexing='ij')
        cmskx = np.sum(np.multiply(xxc, mskcell)) / np.sum(mskcell)
        cmsky = np.sum(np.multiply(yyc, mskcell)) / np.sum(mskcell)
        ax.scatter(cmsky, cmskx, s=600, color='black', marker='x', alpha=0.6)
        ax.axis('off')

    try:
        anim = FuncAnimation(fig, update, frames=nt, interval=330)
        #anim.save(filename+'.mp4', writer='ffmpeg')
        anim.save(filename+'.gif', writer='imagemagick')
        print(f"Animation saved as {filename}")
    except Exception as e:
        print(f"Error occurred: {e}")

    plt.close(fig)

# %%
import matplotlib 
matplotlib.use('Agg')  # Use a non-interactive backend suitable for scripts
model_indc = 0
modelSet[model_indc].trajl = 1 
cell_traj = modelSet[model_indc].trajectories[indtrajs[-10]]
anim_single_cell_trajectory(modelSet[model_indc], cell_traj, x = modelSet[model_indc].Xpca[:, 0:2])

# %%
def cross_correlation(reporter_image_cropMasked, nuclear_image_cropMasked):

    # Flatten the images if they are 2D
    if reporter_image_cropMasked.ndim == 2:
        reporter_image_cropMasked = reporter_image_cropMasked.flatten()
    if nuclear_image_cropMasked.ndim == 2:
        nuclear_image_cropMasked = nuclear_image_cropMasked.flatten()
        
    # Compute correlation coefficient
    correlation_coefficient = np.corrcoef(reporter_image_cropMasked, nuclear_image_cropMasked)[0, 1]
    
    return correlation_coefficient

# %%
# Import single-cell trajectory model from cell-cycle reporter' class
sctm = cellTrajCCR.TrajectoryCCR()
sctm.visual = False
start_frame = 0
filepath = '/home/groups/ZuckermanLab/jalim/LI204601_INCUCYTE/crossCorrCCRnuc/'

# %%
model = filepath+sysName+'_'+conditions[0]+'_1.h5'
print("Model name:", model)
# Load cell cycle reporter and nuclear images and cytoplasm masks
print('initializing...')
sctm.initialize(model, sysName)
# Get all the frames (193 at intervals of 15 minutes) for each model (condition)
sctm.get_frames()
end_frame = sctm.maxFrame
# Get the cell-cycle reporter image and the cytoplasmic mask
sctm.get_imageSet(start_frame, end_frame)
# Get nuclear channel images 
sctm.get_nucImgSet(start_frame, end_frame)
sctm.imgSet_t = np.zeros((end_frame - start_frame + 1, 3))
sctm.get_cell_data()
sctm.get_cell_images()
# Out:
# Model name: /home/groups/ZuckermanLab/jalim/LI204601_INCUCYTE/crossCorrCCRnuc/LI204601_P_A2_1.h5
# initializing...
# Frame 0 has 1 images...
# Frame 1 has 1 images...
# Frame 2 has 1 images...
# Frame 3 has 1 images...
# Frame 4 has 1 images...
# Frame 5 has 1 images...
# Frame 6 has 1 images...
# Frame 7 has 1 images...
# Frame 8 has 1 images...
# Frame 9 has 1 images...
# Frame 10 has 1 images...
# Frame 11 has 1 images...
# Frame 12 has 1 images...
# Frame 13 has 1 images...
# Frame 14 has 1 images...
# Frame 15 has 1 images...
# Frame 16 has 1 images...
# Frame 17 has 1 images...
# Frame 18 has 1 images...
# Frame 19 has 1 images...
# Frame 20 has 1 images...
# Frame 21 has 1 images...
# Frame 22 has 1 images...
# Frame 23 has 1 images...
# Frame 24 has 1 images...
# Frame 25 has 1 images...
# Frame 26 has 1 images...
# Frame 27 has 1 images...
# Frame 28 has 1 images...
# Frame 29 has 1 images...
# Frame 30 has 1 images...
# Frame 31 has 1 images...
# Frame 32 has 1 images...
# Frame 33 has 1 images...
# Frame 34 has 1 images...
# Frame 35 has 1 images...
# Frame 36 has 1 images...
# Frame 37 has 1 images...
# Frame 38 has 1 images...
# Frame 39 has 1 images...
# Frame 40 has 1 images...
# Frame 41 has 1 images...
# Frame 42 has 1 images...
# Frame 43 has 1 images...
# Frame 44 has 1 images...
# Frame 45 has 1 images...
# Frame 46 has 1 images...
# Frame 47 has 1 images...
# Frame 48 has 1 images...
# Frame 49 has 1 images...
# Frame 50 has 1 images...
# Frame 51 has 1 images...
# Frame 52 has 1 images...
# Frame 53 has 1 images...
# Frame 54 has 1 images...
# Frame 55 has 1 images...
# Frame 56 has 1 images...
# Frame 57 has 1 images...
# Frame 58 has 1 images...
# Frame 59 has 1 images...
# Frame 60 has 1 images...
# Frame 61 has 1 images...
# Frame 62 has 1 images...
# Frame 63 has 1 images...
# Frame 64 has 1 images...
# Frame 65 has 1 images...
# Frame 66 has 1 images...
# Frame 67 has 1 images...
# Frame 68 has 1 images...
# Frame 69 has 1 images...
# Frame 70 has 1 images...
# Frame 71 has 1 images...
# Frame 72 has 1 images...
# Frame 73 has 1 images...
# Frame 74 has 1 images...
# Frame 75 has 1 images...
# Frame 76 has 1 images...
# Frame 77 has 1 images...
# Frame 78 has 1 images...
# Frame 79 has 1 images...
# Frame 80 has 1 images...
# Frame 81 has 1 images...
# Frame 82 has 1 images...
# Frame 83 has 1 images...
# Frame 84 has 1 images...
# Frame 85 has 1 images...
# Frame 86 has 1 images...
# Frame 87 has 1 images...
# Frame 88 has 1 images...
# Frame 89 has 1 images...
# Frame 90 has 1 images...
# Frame 91 has 1 images...
# Frame 92 has 1 images...
# Frame 93 has 1 images...
# Frame 94 has 1 images...
# Frame 95 has 1 images...
# Frame 96 has 1 images...
# Frame 97 has 1 images...
# Frame 98 has 1 images...
# Frame 99 has 1 images...
# Frame 100 has 1 images...
# Frame 101 has 1 images...
# Frame 102 has 1 images...
# Frame 103 has 1 images...
# Frame 104 has 1 images...
# Frame 105 has 1 images...
# Frame 106 has 1 images...
# Frame 107 has 1 images...
# Frame 108 has 1 images...
# Frame 109 has 1 images...
# Frame 110 has 1 images...
# Frame 111 has 1 images...
# Frame 112 has 1 images...
# Frame 113 has 1 images...
# Frame 114 has 1 images...
# Frame 115 has 1 images...
# Frame 116 has 1 images...
# Frame 117 has 1 images...
# Frame 118 has 1 images...
# Frame 119 has 1 images...
# Frame 120 has 1 images...
# Frame 121 has 1 images...
# Frame 122 has 1 images...
# Frame 123 has 1 images...
# Frame 124 has 1 images...
# Frame 125 has 1 images...
# Frame 126 has 1 images...
# Frame 127 has 1 images...
# Frame 128 has 1 images...
# Frame 129 has 1 images...
# Frame 130 has 1 images...
# Frame 131 has 1 images...
# Frame 132 has 1 images...
# Frame 133 has 1 images...
# Frame 134 has 1 images...
# Frame 135 has 1 images...
# Frame 136 has 1 images...
# Frame 137 has 1 images...
# Frame 138 has 1 images...
# Frame 139 has 1 images...
# Frame 140 has 1 images...
# Frame 141 has 1 images...
# Frame 142 has 1 images...
# Frame 143 has 1 images...
# Frame 144 has 1 images...
# Frame 145 has 1 images...
# Frame 146 has 1 images...
# Frame 147 has 1 images...
# Frame 148 has 1 images...
# Frame 149 has 1 images...
# Frame 150 has 1 images...
# Frame 151 has 1 images...
# Frame 152 has 1 images...
# Frame 153 has 1 images...
# Frame 154 has 1 images...
# Frame 155 has 1 images...
# Frame 156 has 1 images...
# Frame 157 has 1 images...
# Frame 158 has 1 images...
# frame 15 file 0 with 160 cells
# frame 16 file 0 with 161 cells
# frame 17 file 0 with 162 cells
# frame 18 file 0 with 166 cells
# frame 19 file 0 with 161 cells
# frame 20 file 0 with 156 cells
# frame 21 file 0 with 163 cells
# frame 22 file 0 with 160 cells
# frame 23 file 0 with 160 cells
# frame 24 file 0 with 158 cells
# frame 25 file 0 with 162 cells
# frame 26 file 0 with 165 cells
# frame 27 file 0 with 162 cells
# frame 28 file 0 with 166 cells
# frame 29 file 0 with 164 cells
# frame 30 file 0 with 168 cells
# frame 31 file 0 with 168 cells
# frame 32 file 0 with 166 cells
# frame 33 file 0 with 164 cells
# frame 34 file 0 with 167 cells
# frame 35 file 0 with 158 cells
# frame 36 file 0 with 170 cells
# frame 37 file 0 with 162 cells
# frame 38 file 0 with 160 cells
# frame 39 file 0 with 166 cells
# frame 40 file 0 with 164 cells
# frame 41 file 0 with 169 cells
# frame 42 file 0 with 168 cells
# frame 43 file 0 with 172 cells
# frame 44 file 0 with 173 cells
# frame 45 file 0 with 169 cells
# frame 46 file 0 with 174 cells
# frame 47 file 0 with 173 cells
# frame 48 file 0 with 176 cells
# frame 49 file 0 with 172 cells
# frame 50 file 0 with 177 cells
# frame 51 file 0 with 177 cells
# frame 52 file 0 with 181 cells
# frame 53 file 0 with 178 cells
# Absolute cell number difference b/w two consecutive frames (images) =  170
# Replaced image and masks data of Frame  54
# frame 54 file 0 with 178 cells
# frame 55 file 0 with 177 cells
# frame 56 file 0 with 177 cells
# frame 57 file 0 with 177 cells
# frame 58 file 0 with 175 cells
# frame 59 file 0 with 180 cells
# frame 60 file 0 with 179 cells
# frame 61 file 0 with 180 cells
# frame 62 file 0 with 185 cells
# frame 63 file 0 with 186 cells
# frame 64 file 0 with 189 cells
# frame 65 file 0 with 191 cells
# frame 66 file 0 with 189 cells
# frame 67 file 0 with 192 cells
# frame 68 file 0 with 191 cells
# frame 69 file 0 with 193 cells
# Absolute cell number difference b/w two consecutive frames (images) =  184
# Replaced image and masks data of Frame  70
# frame 70 file 0 with 193 cells
# frame 71 file 0 with 199 cells
# frame 72 file 0 with 200 cells
# frame 73 file 0 with 204 cells
# frame 74 file 0 with 198 cells
# frame 75 file 0 with 197 cells
# frame 76 file 0 with 208 cells
# frame 77 file 0 with 209 cells
# frame 78 file 0 with 211 cells
# Absolute cell number difference b/w two consecutive frames (images) =  62
# Replaced image and masks data of Frame  79
# frame 79 file 0 with 211 cells
# frame 80 file 0 with 211 cells
# frame 81 file 0 with 214 cells
# frame 82 file 0 with 212 cells
# frame 83 file 0 with 216 cells
# frame 84 file 0 with 217 cells
# frame 85 file 0 with 216 cells
# frame 86 file 0 with 222 cells
# frame 87 file 0 with 229 cells
# frame 88 file 0 with 234 cells
# frame 89 file 0 with 237 cells
# frame 90 file 0 with 234 cells
# frame 91 file 0 with 233 cells
# frame 92 file 0 with 242 cells
# frame 93 file 0 with 244 cells
# frame 94 file 0 with 250 cells
# frame 95 file 0 with 253 cells
# frame 96 file 0 with 253 cells
# frame 97 file 0 with 259 cells
# frame 98 file 0 with 266 cells
# frame 99 file 0 with 261 cells
# frame 100 file 0 with 259 cells
# frame 101 file 0 with 266 cells
# frame 102 file 0 with 262 cells
# frame 103 file 0 with 268 cells
# frame 104 file 0 with 262 cells
# Absolute cell number difference b/w two consecutive frames (images) =  83
# Replaced image and masks data of Frame  105
# frame 105 file 0 with 262 cells
# frame 106 file 0 with 267 cells
# frame 107 file 0 with 274 cells
# frame 108 file 0 with 276 cells
# frame 109 file 0 with 277 cells
# frame 110 file 0 with 285 cells
# frame 111 file 0 with 287 cells
# frame 112 file 0 with 280 cells
# frame 113 file 0 with 283 cells
# frame 114 file 0 with 288 cells
# frame 115 file 0 with 289 cells
# frame 116 file 0 with 293 cells
# frame 117 file 0 with 289 cells
# frame 118 file 0 with 292 cells
# frame 119 file 0 with 301 cells
# frame 120 file 0 with 298 cells
# frame 121 file 0 with 297 cells
# frame 122 file 0 with 299 cells
# frame 123 file 0 with 307 cells
# frame 124 file 0 with 313 cells
# frame 125 file 0 with 311 cells
# frame 126 file 0 with 314 cells
# frame 127 file 0 with 321 cells
# frame 128 file 0 with 318 cells
# frame 129 file 0 with 318 cells
# frame 130 file 0 with 325 cells
# frame 131 file 0 with 327 cells
# frame 132 file 0 with 325 cells
# frame 133 file 0 with 325 cells
# frame 134 file 0 with 334 cells
# frame 135 file 0 with 332 cells
# frame 136 file 0 with 332 cells
# frame 137 file 0 with 329 cells
# frame 138 file 0 with 338 cells
# frame 139 file 0 with 330 cells
# frame 140 file 0 with 308 cells
# frame 141 file 0 with 341 cells
# frame 142 file 0 with 340 cells
# frame 143 file 0 with 342 cells
# frame 144 file 0 with 345 cells
# frame 145 file 0 with 343 cells
# frame 146 file 0 with 343 cells
# frame 147 file 0 with 353 cells
# frame 148 file 0 with 347 cells
# frame 149 file 0 with 358 cells
# frame 150 file 0 with 357 cells
# frame 151 file 0 with 349 cells
# frame 152 file 0 with 361 cells
# frame 153 file 0 with 364 cells
# frame 154 file 0 with 372 cells
# frame 155 file 0 with 373 cells
# frame 156 file 0 with 369 cells
# frame 157 file 0 with 378 cells
# frame 158 file 0 with 363 cells
# frame 159 file 0 with 378 cells
# frame 160 file 0 with 375 cells
# frame 161 file 0 with 379 cells
# frame 162 file 0 with 378 cells
# frame 163 file 0 with 385 cells
# frame 164 file 0 with 378 cells
# frame 165 file 0 with 378 cells
# frame 166 file 0 with 387 cells
# frame 167 file 0 with 384 cells
# frame 168 file 0 with 396 cells
# frame 169 file 0 with 389 cells
# frame 170 file 0 with 392 cells
# frame 171 file 0 with 398 cells
# frame 172 file 0 with 407 cells
# frame 173 file 0 with 407 cells
# frame 174 file 0 with 406 cells
# frame 175 file 0 with 415 cells
# frame 176 file 0 with 418 cells
# frame 177 file 0 with 408 cells
# frame 178 file 0 with 421 cells
# frame 179 file 0 with 422 cells
# frame 180 file 0 with 426 cells
# frame 181 file 0 with 431 cells
# frame 182 file 0 with 430 cells
# frame 183 file 0 with 428 cells
# frame 184 file 0 with 430 cells
# frame 185 file 0 with 431 cells
# frame 186 file 0 with 434 cells
# frame 187 file 0 with 433 cells
# frame 188 file 0 with 430 cells
# frame 189 file 0 with 436 cells
# frame 190 file 0 with 444 cells
# frame 191 file 0 with 439 cells
# frame 192 file 0 with 442 cells
# loading cells from frame 0 image 0
# loading cells from frame 1 image 0
# loading cells from frame 2 image 0
# loading cells from frame 3 image 0
# loading cells from frame 4 image 0
# loading cells from frame 5 image 0
# loading cells from frame 6 image 0
# loading cells from frame 7 image 0
# loading cells from frame 8 image 0
# loading cells from frame 9 image 0
# loading cells from frame 10 image 0
# loading cells from frame 11 image 0
# loading cells from frame 12 image 0
# loading cells from frame 13 image 0
# loading cells from frame 14 image 0
# loading cells from frame 15 image 0
# loading cells from frame 16 image 0
# loading cells from frame 17 image 0
# loading cells from frame 18 image 0
# loading cells from frame 19 image 0
# loading cells from frame 20 image 0
# loading cells from frame 21 image 0
# loading cells from frame 22 image 0
# loading cells from frame 23 image 0
# loading cells from frame 24 image 0
# loading cells from frame 25 image 0
# loading cells from frame 26 image 0
# loading cells from frame 27 image 0
# loading cells from frame 28 image 0
# loading cells from frame 29 image 0
# loading cells from frame 30 image 0
# loading cells from frame 31 image 0
# loading cells from frame 32 image 0
# loading cells from frame 33 image 0
# loading cells from frame 34 image 0
# loading cells from frame 35 image 0
# loading cells from frame 36 image 0
# loading cells from frame 37 image 0
# loading cells from frame 38 image 0
# loading cells from frame 39 image 0
# loading cells from frame 40 image 0
# loading cells from frame 41 image 0
# loading cells from frame 42 image 0
# loading cells from frame 43 image 0
# loading cells from frame 44 image 0
# loading cells from frame 45 image 0
# loading cells from frame 46 image 0
# loading cells from frame 47 image 0
# loading cells from frame 48 image 0
# loading cells from frame 49 image 0
# loading cells from frame 50 image 0
# loading cells from frame 51 image 0
# loading cells from frame 52 image 0
# loading cells from frame 53 image 0
# loading cells from frame 54 image 0
# loading cells from frame 55 image 0
# loading cells from frame 56 image 0
# loading cells from frame 57 image 0
# loading cells from frame 58 image 0
# loading cells from frame 59 image 0
# loading cells from frame 60 image 0
# loading cells from frame 61 image 0
# loading cells from frame 62 image 0
# loading cells from frame 63 image 0
# loading cells from frame 64 image 0
# loading cells from frame 65 image 0
# loading cells from frame 66 image 0
# loading cells from frame 67 image 0
# loading cells from frame 68 image 0
# loading cells from frame 69 image 0
# loading cells from frame 70 image 0
# loading cells from frame 71 image 0
# loading cells from frame 72 image 0
# loading cells from frame 73 image 0
# loading cells from frame 74 image 0
# loading cells from frame 75 image 0
# loading cells from frame 76 image 0
# loading cells from frame 77 image 0
# loading cells from frame 78 image 0
# loading cells from frame 79 image 0
# loading cells from frame 80 image 0
# loading cells from frame 81 image 0
# loading cells from frame 82 image 0
# loading cells from frame 83 image 0
# loading cells from frame 84 image 0
# loading cells from frame 85 image 0
# loading cells from frame 86 image 0
# loading cells from frame 87 image 0
# loading cells from frame 88 image 0
# loading cells from frame 89 image 0
# loading cells from frame 90 image 0
# loading cells from frame 91 image 0
# loading cells from frame 92 image 0
# loading cells from frame 93 image 0
# loading cells from frame 94 image 0
# loading cells from frame 95 image 0
# loading cells from frame 96 image 0
# loading cells from frame 97 image 0
# loading cells from frame 98 image 0
# loading cells from frame 99 image 0
# loading cells from frame 100 image 0
# loading cells from frame 101 image 0
# loading cells from frame 102 image 0
# loading cells from frame 103 image 0
# loading cells from frame 104 image 0
# loading cells from frame 105 image 0
# loading cells from frame 106 image 0
# loading cells from frame 107 image 0
# loading cells from frame 108 image 0
# loading cells from frame 109 image 0
# loading cells from frame 110 image 0
# loading cells from frame 111 image 0
# loading cells from frame 112 image 0
# loading cells from frame 113 image 0
# loading cells from frame 114 image 0
# loading cells from frame 115 image 0
# loading cells from frame 116 image 0
# loading cells from frame 117 image 0
# loading cells from frame 118 image 0
# loading cells from frame 119 image 0
# loading cells from frame 120 image 0
# loading cells from frame 121 image 0
# loading cells from frame 122 image 0
# loading cells from frame 123 image 0
# loading cells from frame 124 image 0
# loading cells from frame 125 image 0
# loading cells from frame 126 image 0
# loading cells from frame 127 image 0
# loading cells from frame 128 image 0
# loading cells from frame 129 image 0
# loading cells from frame 130 image 0
# loading cells from frame 131 image 0
# loading cells from frame 132 image 0
# loading cells from frame 133 image 0
# loading cells from frame 134 image 0
# loading cells from frame 135 image 0
# loading cells from frame 136 image 0
# loading cells from frame 137 image 0
# loading cells from frame 138 image 0
# loading cells from frame 139 image 0
# loading cells from frame 140 image 0
# loading cells from frame 141 image 0
# loading cells from frame 142 image 0
# loading cells from frame 143 image 0
# loading cells from frame 144 image 0
# loading cells from frame 145 image 0
# loading cells from frame 146 image 0
# loading cells from frame 147 image 0
# loading cells from frame 148 image 0
# loading cells from frame 149 image 0
# loading cells from frame 150 image 0
# loading cells from frame 151 image 0
# loading cells from frame 152 image 0
# loading cells from frame 153 image 0
# loading cells from frame 154 image 0
# loading cells from frame 155 image 0
# loading cells from frame 156 image 0
# loading cells from frame 157 image 0
# loading cells from frame 158 image 0
# loading cells from frame 159 image 0
# loading cells from frame 160 image 0
# loading cells from frame 161 image 0
# loading cells from frame 162 image 0
# loading cells from frame 163 image 0
# loading cells from frame 164 image 0
# loading cells from frame 165 image 0
# loading cells from frame 166 image 0
# loading cells from frame 167 image 0
# loading cells from frame 168 image 0
# loading cells from frame 169 image 0
# loading cells from frame 170 image 0
# loading cells from frame 171 image 0
# loading cells from frame 172 image 0
# loading cells from frame 173 image 0
# loading cells from frame 174 image 0
# loading cells from frame 175 image 0
# loading cells from frame 176 image 0
# loading cells from frame 177 image 0
# loading cells from frame 178 image 0
# loading cells from frame 179 image 0
# loading cells from frame 180 image 0
# loading cells from frame 181 image 0
# loading cells from frame 182 image 0
# loading cells from frame 183 image 0
# loading cells from frame 184 image 0
# loading cells from frame 185 image 0
# loading cells from frame 186 image 0
# loading cells from frame 187 image 0
# loading cells from frame 188 image 0
# loading cells from frame 189 image 0
# loading cells from frame 190 image 0
# loading cells from frame 191 image 0
# loading cells from frame 192 image 0

# %%
###################### To save as an animation ########################
model_indc = 0
tid = 9 # Trajectory number from the end of the array 
save_file_indc = indtrajs[-tid]
cell_traj = modelSet[model_indc].trajectories[indtrajs[-tid]]
#### Plot of cell coordinates and images along a single-cell trajectory #### 
border_margin = 2
nt = cell_traj.size # Number of single-cell trajectory snippets
fig, axs = plt.subplots(1, 4, figsize = (20, 5))
fig.tight_layout()  # Adjust subplots to fit into the figure area
frames_traj = []
cross_corr = []
def update(itt):
    clear_output(wait = True)
    for ax in axs:
        ax.clear()
    #fig, axs = plt.subplots(1, 4, figsize = (24, 5))
    indcells = np.array([cell_traj[itt]]) # Index of a cell along its trajectory 
    fid = modelSet[model_indc].cells_frameSet[indcells[0]]
    # Originally bordersize = 80, kept by JC
    modelSet[model_indc].get_single_cell_borders(indcells = indcells[0], bordersize = border_margin) 
    imgcell = modelSet[model_indc].cellborder_imgs[0]
    mskcell = modelSet[model_indc].cellborder_msks[0]
    fmskcell = modelSet[model_indc].cellborder_fmsks[0]
    ccborder, csborder = modelSet[model_indc].get_cc_cs_border(mskcell, fmskcell)
    
    axs[0].imshow(np.ma.masked_where(fmskcell == 0, imgcell), cmap = plt.cm.seismic, clim = (-5, 5), alpha = 1.0)
    axs[0].imshow(np.ma.masked_where(fmskcell == 1, imgcell), cmap = plt.cm.gray, clim = (-5, 5), alpha = 0.6)
    axs[0].imshow(np.ma.masked_where(ccborder == 1, mskcell, copy = False), cmap = plt.cm.viridis, alpha = 0.2)
    nx = imgcell.shape[0]
    ny = imgcell.shape[1]
    xxc, yyc = np.meshgrid(np.arange(nx), np.arange(ny), indexing='ij')
    cmskx = np.sum(np.multiply(xxc, mskcell))/np.sum(mskcell)
    cmsky = np.sum(np.multiply(yyc, mskcell))/np.sum(mskcell)
    axs[0].scatter(cmsky, cmskx, s = 1000, color = 'black', marker = 'x', alpha = 0.6)
    axs[0].axis('off')
    
    reporter_image = sctm.imgSet[fid] # Cell cycle reporter image 
    nuclear_image = sctm.nucImgSet[fid] # Nuclear channel image
    reporter_image = np.array(reporter_image)   
    nuclear_image = np.array(nuclear_image)
    x_min = modelSet[model_indc].xmin
    y_min = modelSet[model_indc].ymin
    x_max = modelSet[model_indc].xmax
    y_max = modelSet[model_indc].ymax
   
    # Crop the reporter and nuclear images as per the cell mask 
    cropped_reporter_image = reporter_image[x_min:x_max, y_min:y_max]
    cropped_nuclear_image = nuclear_image[x_min:x_max, y_min:y_max]
    # Calculate cross-correlation between cell-cycle reporter and nuclear channel images 
    cross_corr_frame = cross_correlation(cropped_reporter_image, cropped_nuclear_image)
    cross_corr.append(cross_corr_frame)
    frames_traj.append(fid)
    axs[1].imshow(np.ma.masked_where(mskcell == 0, cropped_reporter_image, copy = False), cmap = plt.cm.gray, clim = (-5, 5), alpha = 0.6)
    axs[1].set_title('Reporter channel')
    axs[1].axis('off')
    axs[2].imshow(np.ma.masked_where(mskcell == 0, cropped_nuclear_image, copy = False), cmap = plt.cm.gray, clim = (-5, 5), alpha = 0.6)
    axs[2].set_title('Nuclear channel')
    axs[2].axis('off')
    axs[3].plot(frames_traj, cross_corr, color = 'b', marker = 'o', markersize = 8, markerfacecolor = 'k')
    axs[3].set_xlabel('Frames')
    axs[3].set_ylabel('Cross-correlation b/w reporter and nuclear channel')
    # After updating the content, reapply tight layout
    fig.tight_layout()
    return axs
########################################## CALL TO SAVE IMAGES AS AN ANIMATION ##########################################
anim = FuncAnimation(fig, update, frames=nt, interval=330)
filename = 'single_cell_trajectory_EGF'+str(save_file_indc)+'.gif'
anim.save(filename, writer='pillow')
print(f"Animation saved as {filename}")
plt.close(fig)
# Out:
# extracting cellborders from frame 139 image 0
# Animation saved as single_cell_trajectory_EGF2009.gif

# %%
model_indc = 0
cell_traj = modelSet[model_indc].trajectories[indtrajs[-50]]

#### Plot of cell coordinates and images along a single-cell trajectory #### 
border_margin = 5
nt = cell_traj.size # Number of single-cell trajectory snippets
frames = []
cross_corr = []
for itt in range(nt):
    clear_output(wait = True)
    plt.clf()
    fig, axs = plt.subplots(1, 4, figsize = (20, 5))
    indcells = np.array([cell_traj[itt]]) # Index of a cell along its trajectory 
    fid = modelSet[model_indc].cells_frameSet[indcells[0]]
    # Originally bordersize = 80, kept by JC
    modelSet[model_indc].get_single_cell_borders(indcells = indcells[0], bordersize = border_margin) 
    imgcell = modelSet[model_indc].cellborder_imgs[0]
    mskcell = modelSet[model_indc].cellborder_msks[0]
    fmskcell = modelSet[model_indc].cellborder_fmsks[0]
    ccborder, csborder = modelSet[model_indc].get_cc_cs_border(mskcell, fmskcell)

    axs[0].imshow(np.ma.masked_where(fmskcell == 0, imgcell), cmap = plt.cm.seismic, clim = (-5, 5), alpha = 1.0)
    axs[0].imshow(np.ma.masked_where(fmskcell == 1, imgcell), cmap = plt.cm.gray, clim = (-5, 5), alpha = 0.6)
    axs[0].imshow(np.ma.masked_where(ccborder == 1, mskcell, copy = False), cmap = plt.cm.viridis, alpha = 0.2)
    nx = imgcell.shape[0]
    ny = imgcell.shape[1]
    xxc, yyc = np.meshgrid(np.arange(nx), np.arange(ny), indexing='ij')
    cmskx = np.sum(np.multiply(xxc, mskcell))/np.sum(mskcell)
    cmsky = np.sum(np.multiply(yyc, mskcell))/np.sum(mskcell)
    axs[0].scatter(cmsky, cmskx, s = 600, color = 'black', marker = 'x', alpha = 0.6)
    axs[0].axis('off')
    
    reporter_image = sctm.imgSet[fid] # Cell cycle reporter image 
    nuclear_image = sctm.nucImgSet[fid] # Nuclear channel image
    reporter_image = np.array(reporter_image)   
    nuclear_image = np.array(nuclear_image)
    x_min = modelSet[model_indc].xmin
    y_min = modelSet[model_indc].ymin
    x_max = modelSet[model_indc].xmax
    y_max = modelSet[model_indc].ymax
   
    # Crop the reporter and nuclear images as per the cell mask 
    cropped_reporter_image = reporter_image[x_min:x_max, y_min:y_max]
    cropped_nuclear_image = nuclear_image[x_min:x_max, y_min:y_max]
    # Calculate cross-correlation between cell-cycle reporter and nuclear channel images 
    cross_corr_frame = cross_correlation(cropped_reporter_image, cropped_nuclear_image)
    cross_corr.append(cross_corr_frame)
    frames.append(fid)
    axs[1].imshow(np.ma.masked_where(mskcell == 0, cropped_reporter_image), cmap = plt.cm.gray, clim = (-5, 5), alpha = 0.6)
    axs[1].set_title('Reporter channel')
    axs[1].axis('off')
    axs[2].imshow(np.ma.masked_where(mskcell == 0, cropped_nuclear_image), cmap = plt.cm.gray, clim = (-5, 5), alpha = 0.6)
    axs[2].set_title('Nuclear channel')
    axs[2].axis('off')
    axs[3].plot(frames, cross_corr, color = 'b', marker = 'o', markersize = 8, markerfacecolor = 'k')
    axs[3].set_xlabel('Frames')
    axs[3].set_ylabel('Cross correlation b/w reporter and nuclear channel')
    fig.tight_layout()  # Adjust subplots to fit into the figure area
    plt.show()
    plt.pause(0.33)
# Out:
# extracting cellborders from frame 95 image 0

# %%
plt.clf()
plt.plot(frames, cross_corr, color = 'b', marker = 'o', markersize = 8)
plt.show()

# %%
file_dump = sysName+'_cell_cycRep_'+date2day+'OSM1_regs'+str(single_cell_traj_test_ind)+'.dat'

# %%
with open(file_dump, "w") as fp:
    # Keyword can be added as enumerate(conditions, start = 1) to start from other than '0' (default)
    for icond, conds in enumerate(conditions): 
        average_cross_corr = []
        #cross_correlation = np.zeros((nframes, nfovs), dtype=np.float64)
        for ifov in fovs:
            model = filepath+sysName+'_'+conditions[icond]+'_'+str(ifov)+'.h5'
            print("Model name:", model)
            # Load cell cycle reporter and nuclear images and cytoplasm masks
            print('initializing...')
            sctm.initialize(model, sysName)
            # Get all the frames (193 at intervals of 15 minutes) for each model (condition)
            sctm.get_frames()
            #end_frame = sctm.maxFrame
            end_frame = len(inds_test_cell_traj) - 1
            #end_frame = 2
            # Get the cell-cycle reporter image and the cytoplasmic mask
            sctm.get_imageSet(start_frame, end_frame)
            # Get nuclear channel images 
            sctm.get_nucImgSet(start_frame, end_frame)
            #sctm.imgSet_t = np.zeros((end_frame - start_frame + 1, 3))
            sctm.get_cell_data()
            sctm.get_cell_images()
            num_cells_stack = 0
            cross_corr_CCRnuc = [] # Cross-correlations between cell-cycle reporter and nuclear channel images
            for im in range(start_frame, end_frame):
               
                reporter_image = sctm.imgSet[im] # Cell cycle reporter image
                nuclear_image = sctm.nucImgSet[im] # Nuclear channel image
                reporter_image = np.array(reporter_image)   
                nuclear_image = np.array(nuclear_image) 
                # Get the right indices to extract cellular info
                cells_inds_framewise = np.where(sctm.cells_indimgSet == im)[0]
                num_cells_per_frame = cells_inds_framewise.size
                # Get cell index from absolute cell indices of the longest (test) single-cell trajectory across frames 
                #cell_index_abs = cell_inds_longest_traj[im]
                cell_index_abs = inds_test_cell_traj[im]
                cell_index_frame = cell_index_abs - num_cells_stack # Cell index within a frame
                #print("Local index of a chosen cell: ",cell_index_frame)
                cell_mask = sctm.cells_msks[cell_index_frame] # Get mask of a selected cell
                cell_position_mask = sctm.x[cell_index_frame] # Get the position of a selected cell
                num_cells_stack += num_cells_per_frame # Counter for the number of cells in all frames (stack)
                # Cross-correlation between cell-cycle reporter and nuclear channel by exploiting cellular masks 
                #cross_correlation[im][ifov-1] = masked_cross_correlation(reporter_image,
                print("Cross-correlation b/w cell-cycle reporter and nuclear images of frame: ",im + 1)
                cross_correlation = masked_cross_correlation(reporter_image, nuclear_image, cell_mask, cell_position_mask)
                cross_corr_CCRnuc.append(cross_correlation)
                #plot_cropped_masked_regions(reporter_image, nuclear_image, cell_mask, cell_position_mask)
                #debug_visualization(reporter_image, nuclear_image, cell_mask, cell_position_mask)
                #plot_image_regions_under_mask(reporter_image, nuclear_image, cell_mask, cell_position_mask)
        #average_cross_corr = np.nanmean(cross_correlation, axis = 1, dtype=np.float64) # average over FOVs
        average_cross_corr = cross_corr_CCRnuc # In case of one FOV
        #average_cross_corr = average_cross_corr.reshape(1, nframes)
        fp.write(str(average_cross_corr) + "\n")

# %%
# Masked cross-correlation between cell-cycle reporter and nuclear channel images
def masked_cross_correlation(image1, image2, cell_masks, cell_positions_mask):
    """
    Compute the cross-correlation between two images within a specified mask.
    :param image1: First image (e.g., cell cycle reporter channel).
    :param image2: Second image (e.g., nuclear channel).
    :param mask_cyto: 2D array where each 'pixel' is a binary mask for a single cell.
    :return: Array of cross-correlation values for each cell.
    """
        
    # Ensure the mask is a boolean
    cell_mask = cell_masks.astype(bool)

    # Place each cell mask into the full mask and apply it to the image
    full_cell_mask = np.zeros_like(image1, dtype=bool)
    # Determine the position for this cell mask
    y, x = cell_positions_mask # Replace with the actual coordinates for this mask
    y, x = int(y), int(x)  # Convert to integers
    
    # Adjust coordinates: if negative then make them positive
    y = max(y, 0)
    x = max(x, 0)

    # Calculate cropping dimensions
    max_y, max_x = full_cell_mask.shape
    crop_y = min(cell_mask.shape[0], max_y - y)
    crop_x = min(cell_mask.shape[1], max_x - x)
    crop_y, crop_x = int(crop_y), int(crop_x)  # Convert to integers

    # Check for valid cropping dimensions
    if crop_y > 0 and crop_x > 0:
        cropped_mask = cell_mask[:crop_y, :crop_x]
        full_cell_mask[y:y+crop_y, x:x+crop_x] = cropped_mask

    # Masked images: np.nan is replaced by 0 
    masked_img1 = np.where(full_cell_mask, image1.astype(np.float32), 0)
    masked_img2 = np.where(full_cell_mask, image2.astype(np.float32), 0)
    """   
    # Ensure there are no NaN values that could corrupt the sum
    nan_mask = np.logical_or(np.isnan(masked_img1), np.isnan(masked_img2))
    valid_mask = np.logical_not(nan_mask)
        
    # Compute cross-correlation only on valid (non-NaN) pixels
    valid_img1 = masked_img1[valid_mask]
    valid_img2 = masked_img2[valid_mask]
    """    
    # Normalize the valid pixel values
    #norm_img1 = z_normalize(valid_img1)
    #norm_img2 = z_normalize(valid_img2)
    norm_img1 = z_normalize(masked_img1)
    norm_img2 = z_normalize(masked_img2)
    
    # Compute the cross-correlation
    #cross_corrs = correlate2d(norm_img1, norm_img2, mode = 'same', boundary = 'fill', fillvalue = 0)
    cross_corr_matrix = fftconvolve(norm_img1, norm_img2[::-1, ::-1], mode='same')
    # Normalize the cross-correlation to get values between -1 and +1
    num_elements = np.prod(norm_img1.shape)  # Number of elements (pixels) in the images
    # std_dev_product = np.std(norm_img1)*np.std(norm_img2)  # Product of standard deviations
    # normalized_cross_corr = np.sum(cross_corr_matrix)/(num_elements * std_dev_product)
    # normalized_cross_corr = np.sum(cross_corr_matrix)/num_elements
    # Summing all the pixel correlation values to get a single cross-correlation value
    # cross_corrs = np.sum(cross_corr_matrix)
    # Compute the auto-correlations at zero lag
    auto_corr_1 = np.sum(norm_img1 * norm_img1)
    auto_corr_2 = np.sum(norm_img2 * norm_img2)

    # Normalize the cross-correlation
    normalized_cross_corr = np.sum(cross_corr_matrix)/np.sqrt(auto_corr_1*auto_corr_2)

    return normalized_cross_corr

# %%
with open(file_dump, "a") as fp:
    # Keyword can be added as enumerate(conditions, start = 1) to start from other than '0' (default)
    for icond, conds in enumerate(conditions): 
        average_cross_corr = []
        #cross_correlation = np.zeros((nframes, nfovs), dtype=np.float64)
        for ifov in fovs:
            model = filepath+sysName+'_'+conditions[icond]+'_'+str(ifov)+'.h5'
            print("Model name:", model)
            # Load cell cycle reporter and nuclear images and cytoplasm masks
            print('initializing...')
            sctm.initialize(model, sysName)
            # Get all the frames (193 at intervals of 15 minutes) for each model (condition)
            sctm.get_frames()
            end_frame = sctm.maxFrame
            #end_frame = 2
            # Get nuclear channel images 
            sctm.get_nucChanImgs(end_frame)
            # Cell cycle reporter images and cell mask
            sctm.get_imageSet(start_frame, end_frame)
            sctm.imgSet_t = np.zeros((end_frame - start_frame + 1, 3))
            sctm.get_cell_data()
            sctm.get_cell_images()
            num_cells_stack = 0
            cross_corr_CCRnuc = [] # Cross-correlations between cell-cycle reporter and nuclear channel images
            for im in range(start_frame, end_frame + 1):
               
                reporter_image = sctm.imgSet[im] # Cell cycle reporter image
                nuclear_image = sctm.nucImgSet[im] # Nuclear channel image
                reporter_image = np.array(reporter_image)   
                nuclear_image = np.array(nuclear_image) 
                
                # Get the right indices to extract cellular info
                cells_inds_framewise = np.where(sctm.cells_indimgSet == im)[0]
                num_cells_per_frame = cells_inds_framewise.size
                # Get cell index from absolute cell indices of the longest single-cell trajectory across frames 
                cell_index_abs = cell_inds_longest_traj[im]
                cell_index_frame = cell_index_abs - num_cells_stack # Cell index within a frame
                cell_mask = sctm.cells_msks[cell_index_frame] # Get mask of a selected cell
                cell_position_mask = sctm.x[cell_index_frame] # Get position of a selected cell
                # Convert position indices into integers
                #cell_position_mask = [(int(y), int(x)) for y, x in cell_position_mask] 
                num_cells_stack += num_cells_per_frame # Counter for number of cells in all frames (stack)
                """
                # Convert the cutout mask to a full-sized mask
                full_size_mask = create_full_sized_mask(cell_mask.astype(bool),
                                                        cell_position_mask, reporter_image.shape)
                cell_region = extract_cell_region(reporter_image, full_size_mask)
                avg_intensity = calculate_average_intensity(cell_region)
                std_image = create_standardized_intensity_image(avg_intensity)
                standardized_images = std_image
                """
                # Cross-correlation between cell-cycle reporter and nuclear channel by exploiting cellular masks 
                #cross_correlation[im][ifov-1] = masked_cross_correlation(reporter_image,
                cross_correlation = masked_cross_correlation(reporter_image, 
                                                                         nuclear_image, 
                                                                         cell_mask,
                                                                         cell_position_mask)
                cross_corr_CCRnuc.append(cross_correlation)
        #average_cross_corr = np.nanmean(cross_correlation, axis = 1, dtype=np.float64) # average over FOVs
        average_cross_corr = cross_corr_CCRnuc # In case of one FOV
        #average_cross_corr = average_cross_corr.reshape(1, nframes)
        fp.write(str(average_cross_corr) + "\n")

# %%
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
import matplotlib
    
def extract_cell_region(reporter_image, cell_mask):
    # Extract the cell region from the reporter image using the cell mask
    return reporter_image*cell_mask

def calculate_average_intensity(region):
    # Calculate the average intensity of a non-zero region
    nonzero_values = region[region > 0]
    return np.mean(nonzero_values) if nonzero_values.size > 0 else 0

def create_standardized_intensity_image(average_intensity, size=(50, 50)):
    # Create a standardized size image filled with the average intensity
    return np.full(size, average_intensity)
